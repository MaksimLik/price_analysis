# %% [markdown]
# # Statystyka i analiza danych

# %% [markdown]
# Sprawozdanie przygotowane: Maksim Likhaivanenka 150251 I5.1 Informatyka
#
# Dane są pobrane z Wikipedii za 2018 rok, dane zebrane w sposób tablicy (ceny są powiązane z nazwami gier), dane są z obserwacji.
#
# Cel: zbadać czy kupować gry w Media Expert wygodniej niż w sklepie Play Station.

# %% [markdown]
# ### Statystyka Opisowa

# %% [markdown]
# W tej statystyce obliczyłem (średnią, wariancję próby, odchylenie standardowe próby). Nie obliczyłem mediany i dominanty bo one są nie potrzebne dla innych obliczeń i nie mają wpływu.
#
# Tablica z danymi:

# %%
#Ceny w Media Expert
Media_Expert <- c(245, 134.99, 149, 104.99, 134.99, 119.99, 99.99, 200.65, 
145.99, 189.99, 139.99, 149.99, 109.99, 154.99, 89,
147, 149.99, 164.99, 109, 114.99, 67.43, 79.99, 93.08, 99.99, 139, 199.99, 134.99,
134.99, 159, 149.99, 79.99, 139.99, 159, 199.99, 139.99, 139.99, 189.99, 169.99,
178.3, 229, 217, 69.9, 134.99, 99.9, 201.82, 169.9, 110, 139.99, 134.99, 209.68, 62.18)

#Ceny w Play Station 4
PlayStation <- c(249, 169, 169, 125, 169, 169, 124, 289, 145, 259, 169, 169, 149, 119, 124,
124, 169, 145, 159.9, 169, 124, 124, 119.9, 199, 145, 249, 145, 145, 209, 124, 59, 145, 
169, 249, 169, 209, 189, 209, 209, 249, 189.9, 99, 145, 79, 169, 259, 124, 139, 169, 249, 124)

#Nazwy gier
Nazwa_Gry <- c("Gran Turismo Sport", "Uncharted: Lost Legacy", "Crash Bandicoot ", 
"DriveClub", "inFamous: Second Son", "Lego Marvel Super Heroes", "Rayman Legends", "Dirt 4",
"Alien: Isolation", "GTA V", "The Order: 1886", "The Last of Us Remastered", "Diablo3 Ultimate Edition",
"Resident Evil 2 Revelations", "Agents of Mayhem", "Farming Simulator 2015", "Noire", "Sniper: Ghost Warrior 3",
"Rainbow Six Siege", "Lego Jurassic World", "FIFA 16", "Need for Speed 2015", "Assassins Creed Syndicate", "Tom Clancy The Division",
"God of War 3", "Dragon Quest Heroes 2", "Until Dawn", "Uncharted: The Nathan Drake Collection", "Mafia III", "Star Wars Battlefront",
"Just Dance 2016", "Ratchet & Clank", "Watch Dogs", "Battlefield 1 Revolution", "No Mans Sky",
"Dark Souls 3", "Bloodborne GOTY", "MX vs ATV All Out", "Syberia 3", "Street Fighter V",
"Wolfenstein II The New Colossus", "Yesterday Origins", "The Last Guardian", "Mount & Blade: Warband",
"Technomancer", "Tekken 7", "Assetto Corsa", "Plants vs. Zombies Garden Warfare 2",
"Uncharted 4: A Thief's End", "Sudden Strike 4", "Homefront 2: Revolution")

#Różnica cen
Roznica <- c(Media_Expert - PlayStation)

#Wizualizacja danych w formacie tablicy
Nazwa_Gry <- data.frame(Nazwa_Gry = Nazwa_Gry, Media_Expert = Media_Expert, PlayStation = PlayStation, Roznica = Roznica) 

#Wyświetlanie tej tablicy
Nazwa_Gry
# Out:
#    Nazwa_Gry                              Media_Expert PlayStation Roznica
# 1  Gran Turismo Sport                     245.00       249.0        -4.00
# 2  Uncharted: Lost Legacy                 134.99       169.0       -34.01
# 3  Crash Bandicoot                        149.00       169.0       -20.00
# 4  DriveClub                              104.99       125.0       -20.01
# 5  inFamous: Second Son                   134.99       169.0       -34.01
# 6  Lego Marvel Super Heroes               119.99       169.0       -49.01
# 7  Rayman Legends                          99.99       124.0       -24.01
# 8  Dirt 4                                 200.65       289.0       -88.35
# 9  Alien: Isolation                       145.99       145.0         0.99
# 10 GTA V                                  189.99       259.0       -69.01
# 11 The Order: 1886                        139.99       169.0       -29.01
# 12 The Last of Us Remastered              149.99       169.0       -19.01
# ...

# %% [markdown]
# 1. Średnia:
#
# ![Średnia.png](data:image/png;base64,...)

# %% [markdown]
# Tu obliczamy średnią dla naszych danych i robimy to po przez różnicę bo dane są sparowane;
#
# Robimy to przez funkcję:
#
# ```
# mean(nasze dane)
# ```

# %%
#Różnica cen
Roznica <- c(Media_Expert - PlayStation)

Srednia <- c(mean(Roznica))
cat("Średnia wartość:", round(Srednia,3) ,"\n")
# Out:
# Średnia wartość: -24.689

# %% [markdown]
# 2. Wariancja w próbie:
#
# ![wariancja w probie.png](data:image/png;base64,...)

# %% [markdown]
# Kiedy już mamy obliczoną średnią w próbce, to możemy obliczyć i wariancję w tej samej próbie. Więc liczymy wariancję w próbie:

# %%
wariancja <- c(sum((Roznica - Srednia)^2)/(length(Roznica) - 1))
cat("Wariancja próby:", round(wariancja,3) ,"\n")
# Out:
# Wariancja próby: 1007.959

# %% [markdown]
# 3. Odchylenie standardowe dla próby:
#
# ![odchylenie standardowe.png](data:image/png;base64,...)

# %% [markdown]
# Kiedy już mamy wariancję to możemy wyodrębnić pierwiastek z tej wariancji i będziemy mieli odchylenie standardowe albo skorzystać z funckji:
#
#
# ```
# sd(nasze dane)
# ```

# %%
odchyl_stan <- c(round(sd(Roznica), 3))

cat("Odchylenie standardowe próby:", round(odchyl_stan,3) ,"\n")
# Out:
# Odchylenie standardowe próby: 31.748

# %% [markdown]
# ---
#
#
# ***Wykresy i ich analiza:***

# %% [markdown]
# Wyrkres rozrzutu, dla analizy cen w sklepach, z którego wynika, że gry w sklepie PlayStation droższe:

# %%
library(ggplot2)

df <- data.frame(Media_Expert, PlayStation, Nazwa_Gry)
ggplot(df, aes(x=PlayStation, y=Media_Expert)) +
  geom_point() +
  labs(x="Ceny w PlayStation 4", y="Ceny w Media Expert") +
  ggtitle("Porównanie cen gier w Media Expert i PlayStation 4")
# Out:
# plot without title

# %% [markdown]
# Z samego początku zobaczymy wizualizację dla cen z tych 2 sklepów:

# %%
#Ilość prób
n <- seq(1, 51)

#Budowa wykresu
plot(n, PlayStation,type="o",col="red", ylab = "Media Exper, PlayStation (zł.)", 
xlab = "Ilość próbek", main = "Porównanie cen gier 2 sklepów")

lines(n, Media_Expert, type="o", col="green")
# Out:
# Plot with title “Porównanie cen gier 2 sklepów”

# %% [markdown]
# Jak widać na tych wykresach - czerwony kolor w większości przypadków jest wyżej od zielonego.
#
# *Czerwony* kolor - to jest sklep PlayStation;
#
# *Zielony* kolor - to jest sklep Media Expert;
#
# Z tego powodu możemy określić, że gry w sklepie Media Expert są taniej od gier w sklepie PlayStation. Też możemy wziąć pod uwagę obliczoną wcześniej różnicę cen tych dwóch sklepów i wykresie rozrzutu.
#
#
#
# ---
#
#
#
# Dalej sprawdzimy czy rozkład jest normalny:

# %%
hist(Media_Expert, breaks=6, main="With breaks=6")
hist(PlayStation, breaks=7, main="With breaks=7")
# Out:
# Plot with title “With breaks=6”
# Plot with title “With breaks=7”

# %% [markdown]
# Niestety, te histogramy świadczą o tym, że układ jest skośny, tj. nie jest to układ normalny. Dlatego potrzebujemy jeszcze jednego histogramu z różnicą cen.
#
# Ten histogram jest poniżej:

# %%
hist(Roznica, breaks=7, main="With breaks=7")
# Out:
# Plot with title “With breaks=7”

# %% [markdown]
# Tu widzimy, że rozkład nadal nie jest idealny i widać, żę trochę skośny, jednak próbka ma 51 element, dlatego warto byłoby wziąć jeszcze kilkanaście elementów im więcej tym lepiej, ale minimum to > 30 elementów.
#
# Zróbmy wykres końcowy, żeby już wiedzieć - ma być ten rozkład dąży do normalnego:

# %%
qqnorm(Roznica)
qqline(Roznica)
# Out:
# Plot with title “Normal Q-Q Plot”

# %% [markdown]
# Bingo !
#
# Tu widzimy, że rozkład dąży do normalnego, chociaż nie jest idealny, jednak mniej-bardziej stara się trymać tej linii.
#
# To oznacza, że możemy iść dalej.

# %% [markdown]
# ### Test T-Student.

# %% [markdown]
# W związku z tym, że dane są sprowane - obliczyłem ich różnicę, z tej różnicy obliczyłem wartość średnią, wariancję w próbie i odchylenie standardowe w próbie.
#
# Test T wykonujemy dla danych sparowanych jednej populacji przez tę formułę:
#
# ![test T.png](data:image/png;base64,...)

# %%
#Różnica cen
Roznica <- c(Media_Expert - PlayStation)

Srednia <- c(mean(Roznica))

wariancja <- c(sum((Roznica - Srednia)^2)/(length(Roznica) - 1))

odchyl_stan <- c(sqrt(wariancja))

test_T <- c((Srednia - 0)/(odchyl_stan/sqrt(length(Roznica))))
cat("Test Tn-1, dla jednej populacji: T =", round(test_T,3) ,"\n")
# Out:
# Test Tn-1, dla jednej populacji: T = -5.554

# %% [markdown]
# Przy tym teście otrzymujemy T = -5.554;
#
# Obliczymy stopni swobody to będzie ilość naszych danych -1;
#
# Otrzymujemy: 51 - 1 = 50;
#
# Z tego powodu, że chcemy zbadać, czy kupować gry w Media Expert jest wygodniej załózmy, że
#
# H0: µ = 0 (czy ceny są takie same w obydwu sklepach)
#
# H1: µ < 0 (czy ceny Media Expert są mniejsze)
#
# α = 5% = 0.05;
#
# Obliczymy dzięki poleceniu
#
#
# ```
# t.test(Roznica, alternative = c("less"), mu=0)
# ```
# Gdzie Różnica - to są nasze dane;
#
# alternative = c("less") - to oznacza, że badamy znak "<";
#
# mu=0 - to wartość µ którą przyjmujemy za zero przy testowaniu naszej hipotezy;

# %%
t.test(Roznica, alternative = c("less"), mu=0)
# Out:
# 	One Sample t-test
#
# data:  Roznica
# t = -5.5536, df = 50, p-value = 5.359e-07
# alternative hypothesis: true mean is less than 0
# 95 percent confidence interval:
#      -Inf -17.2389
# sample estimates:
# mean of x
# -24.68941

# %% [markdown]
# Tu obliczyliśmy:
#
# T = -5.5536;
#
# Stopni swobody: 30;
#
# 95-procentowy przedział ufności:  -Inf -17.2389, (Inf - to nieskończoność);
#
# Średnia wartość próby X: -24.68941
#
# Wynika, że odrzucamy Hipotezę H0 i akceptujemy Ha.
#
#
#
# ---
#
# Jeśli obliczymy ręcznie to będziemy mieli przedział: (-inf; -2.0423)
#
# Przypominam, że założyliśmy aplha = 5%, mamy 50 stopni swobody i przez te dane odczytujemy naszą wartość: 2.0086;
#
# Wartość jest odczytywana z tej [tablicy](https://www.naukowiec.org/tablice/statystyka/rozklad-t-studenta_248.html).
#
# T znajduje się w przedziale, dlatego odrzucamy Hipotezę zerową i przyjmujemy alternatywną;

# %% [markdown]
# ### Podsumowanie

# %% [markdown]
# Wnioskując mogę stwierdzić, że kupować gry w sklepie Media Expert - wygodniej niż w sklepie PlayStation.
#
# To możemy zobaczyć na wykresach które są w mojej prace i przy testowaniu hipotez, które też mówią o tym, że ceny gier są niższe w sklepie Media Expert niż PlayStation.
#
# Badane sklepy mają zatem cenowo różne oferty.
